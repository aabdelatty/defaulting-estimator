# %%
import pandas as pd
import  matplotlib

# %% [markdown]
# # Common  functions

# %%
def plot_default_per_colm_value(df, colmn_name):
    """
        plot the defaulting distribution per column categories
        Input:
            df: DataFrame of interest
            colmn_name: the column we are interested 
    """
    defaulting_per_colmn = df.groupby('default')[colmn_name].value_counts().unstack(0)
    plot = defaulting_per_colmn.plot(kind="bar", figsize=(15, 5))
    plot.set_title("Distribution of defaulting per " + colmn_name)
    #print(defaulting_per_colmn)
    defaulting_per_colmn = defaulting_per_colmn.div(defaulting_per_colmn.sum(axis=1), axis=0)
    return defaulting_per_colmn

# %% [markdown]
# # Load the Data

# %%
data = pd.read_csv("dataset.csv", sep=";")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99976 entries, 0 to 99975
# Data columns (total 43 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   uuid                                 99976 non-null  object
#  1   default                              89976 non-null  float64
#  2   account_amount_added_12_24m          99976 non-null  int64
#  3   account_days_in_dc_12_24m            88140 non-null  float64
#  4   account_days_in_rem_12_24m           88140 non-null  float64
#  5   account_days_in_term_12_24m          88140 non-null  float64
#  6   account_incoming_debt_vs_paid_0_24m  40661 non-null  float64
#  7   account_status                       45603 non-null  float64
#  8   account_worst_status_0_3m            45603 non-null  float64
#  9   account_worst_status_12_24m          33215 non-null  float64
#  10  account_worst_status_3_6m            42274 non-null  float64
#  11  account_worst_status_6_12m           39626 non-null  float64
#  12  age                                  99976 non-null  int64
#  13  avg_payment_span_0_12m               76140 non-null  float64
#  14  avg_payment_span_0_3m                50671 non-null  float64
#  15  merchant_category                    99976 non-null  object
#  16  merchant_group                       99976 non-null  object
#  17  has_paid                             99976 non-null  bool
#  18  max_paid_inv_0_12m                   99976 non-null  float64
#  19  max_paid_inv_0_24m                   99976 non-null  float64
#  20  name_in_email                        99976 non-null  object
#  21  num_active_div_by_paid_inv_0_12m     77037 non-null  float64
#  22  num_active_inv                       99976 non-null  int64
#  23  num_arch_dc_0_12m                    99976 non-null  int64
#  24  num_arch_dc_12_24m                   99976 non-null  int64
#  25  num_arch_ok_0_12m                    99976 non-null  int64
#  26  num_arch_ok_12_24m                   99976 non-null  int64
#  27  num_arch_rem_0_12m                   99976 non-null  int64
#  28  num_arch_written_off_0_12m           81898 non-null  float64
#  29  num_arch_written_off_12_24m          81898 non-null  float64
#  30  num_unpaid_bills                     99976 non-null  int64
#  31  status_last_archived_0_24m           99976 non-null  int64
#  32  status_2nd_last_archived_0_24m       99976 non-null  int64
#  33  status_3rd_last_archived_0_24m       99976 non-null  int64
#  34  status_max_archived_0_6_months       99976 non-null  int64
#  35  status_max_archived_0_12_months      99976 non-null  int64
#  36  status_max_archived_0_24_months      99976 non-null  int64
#  37  recovery_debt                        99976 non-null  int64
#  38  sum_capital_paid_account_0_12m       99976 non-null  int64
#  39  sum_capital_paid_account_12_24m      99976 non-null  int64
#  40  sum_paid_inv_0_12m                   99976 non-null  int64
#  41  time_hours                           99976 non-null  float64
#  42  worst_status_active_inv              30461 non-null  float64
# dtypes: bool(1), float64(19), int64(19), object(4)
# memory usage: 32.1+ MB

# %% [markdown]
# ## Separate the data into training and testing:
#  - Testing data is the portion of data having default as NA

# %%
train_data = data[data['default'].notnull()]
train_data.to_csv('training_dataset.csv')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89976 entries, 0 to 89975
# Data columns (total 43 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   uuid                                 89976 non-null  object
#  1   default                              89976 non-null  float64
#  2   account_amount_added_12_24m          89976 non-null  int64
#  3   account_days_in_dc_12_24m            79293 non-null  float64
#  4   account_days_in_rem_12_24m           79293 non-null  float64
#  5   account_days_in_term_12_24m          79293 non-null  float64
#  6   account_incoming_debt_vs_paid_0_24m  36619 non-null  float64
#  7   account_status                       41042 non-null  float64
#  8   account_worst_status_0_3m            41042 non-null  float64
#  9   account_worst_status_12_24m          29921 non-null  float64
#  10  account_worst_status_3_6m            38038 non-null  float64
#  11  account_worst_status_6_12m           35663 non-null  float64
#  12  age                                  89976 non-null  int64
#  13  avg_payment_span_0_12m               68508 non-null  float64
#  14  avg_payment_span_0_3m                45594 non-null  float64
#  15  merchant_category                    89976 non-null  object
#  16  merchant_group                       89976 non-null  object
#  17  has_paid                             89976 non-null  bool
#  18  max_paid_inv_0_12m                   89976 non-null  float64
#  19  max_paid_inv_0_24m                   89976 non-null  float64
#  20  name_in_email                        89976 non-null  object
#  21  num_active_div_by_paid_inv_0_12m     69318 non-null  float64
#  22  num_active_inv                       89976 non-null  int64
#  23  num_arch_dc_0_12m                    89976 non-null  int64
#  24  num_arch_dc_12_24m                   89976 non-null  int64
#  25  num_arch_ok_0_12m                    89976 non-null  int64
#  26  num_arch_ok_12_24m                   89976 non-null  int64
#  27  num_arch_rem_0_12m                   89976 non-null  int64
#  28  num_arch_written_off_0_12m           73671 non-null  float64
#  29  num_arch_written_off_12_24m          73671 non-null  float64
#  30  num_unpaid_bills                     89976 non-null  int64
#  31  status_last_archived_0_24m           89976 non-null  int64
#  32  status_2nd_last_archived_0_24m       89976 non-null  int64
#  33  status_3rd_last_archived_0_24m       89976 non-null  int64
#  34  status_max_archived_0_6_months       89976 non-null  int64
#  35  status_max_archived_0_12_months      89976 non-null  int64
#  36  status_max_archived_0_24_months      89976 non-null  int64
#  37  recovery_debt                        89976 non-null  int64
#  38  sum_capital_paid_account_0_12m       89976 non-null  int64
#  39  sum_capital_paid_account_12_24m      89976 non-null  int64
#  40  sum_paid_inv_0_12m                   89976 non-null  int64
#  41  time_hours                           89976 non-null  float64
#  42  worst_status_active_inv              27436 non-null  float64
# dtypes: bool(1), float64(19), int64(19), object(4)
# memory usage: 29.6+ MB

# %%
test_data = data[data['default'].isnull()]
test_data.to_csv('testing_dataset.csv')

# %% [markdown]
# # EDA
#  1. Visualize the label (default) and check for imbalancing
#  2. Get better understanding on how user information and taste might lead to defaulting
#  3. Understand attributes describing loan status
#  4. Do in depth analysis of the account's statues
#  5. Test how the increase of paid/added amounts might reduce the probability of defaulting
#  6. Tap into who active invoices and dept history might correlate with defaulting
#  7. Analyze the Written Off loans
#  8. Determine if other attributes like time_hours is useful for our modeling

# %% [markdown]
# ## 1. Visualize the label (default) and check for imbalancing
#  - Data is very imbalanced: we might need to do over or under sampling
#  - Defaulting occured only in 1.4% of the data

# %%
train_data['default'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='default'>

# %%
default_value_counts = train_data['default'].value_counts()
100 * default_value_counts[1.0]/ sum(default_value_counts)
# Out:
# 1.4314928425357873

# %% [markdown]
# ## 2. Get better understanding on how user information and taste might lead to defaulting
#  - All four attributes of interest (age, name_in_email, merchant_group, and merchant_category) have no null values

# %%
min_age = train_data['age'].min()
max_age = train_data['age'].max()
train_data.groupby('default')['age'].hist(bins=[min_age, 25, 40, 60, max_age])
# Out:
# default
# 0.0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1.0    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: age, dtype: object

# %%
plot_default_per_colm_value(train_data, 'name_in_email')
# Out:
# default          0.0  1.0
# name_in_email
# F               8647  108
# F+L            35904  454
# F1+L            6476   90
# Initials          23    1
# L               1160   28
# L1+F           14319  176
# Nick            7351  145
# no_match       14808  286
# default             0.0       1.0
# name_in_email
# F              0.987664  0.012336
# F+L            0.987513  0.012487
# F1+L           0.986293  0.013707
# Initials       0.958333  0.041667
# L              0.976431  0.023569
# L1+F           0.987858  0.012142
# Nick           0.980656  0.019344
# no_match       0.981052  0.018948

# %%
plot_default_per_colm_value(train_data, 'merchant_group')
# Out:
# default                   0.0  1.0
# merchant_group
# Automotive Products       831   17
# Children Products        4556   58
# Clothing & Shoes        14692  341
# Electronics              2641   63
# Entertainment           43614  326
# Erotic Materials          644   26
# Food & Beverage           300   30
# Health & Beauty          6485  104
# Home & Garden            3288   62
# Intangible products       952   65
# Jewelry & Accessories     929   17
# Leisure, Sport & Hobby   9756  179
# default                      0.0       1.0
# merchant_group
# Automotive Products     0.979953  0.020047
# Children Products       0.987430  0.012570
# Clothing & Shoes        0.977317  0.022683
# Electronics             0.976701  0.023299
# Entertainment           0.992581  0.007419
# Erotic Materials        0.961194  0.038806
# Food & Beverage         0.909091  0.090909
# Health & Beauty         0.984216  0.015784
# Home & Garden           0.981493  0.018507
# Intangible products     0.936087  0.063913
# Jewelry & Accessories   0.982030  0.017970
# Leisure, Sport & Hobby  0.981983  0.018017

# %%
default_per_permerchant_category = plot_default_per_colm_value(train_data, 'merchant_category')
# Out:
# default                                                 0.0    1.0
# merchant_category
# Adult Shoes & Clothing                                265.0    7.0
# Automotive Parts & Accessories                        738.0   11.0
# Bags & Wallets                                         21.0    NaN
# Body & Hair Care                                      752.0   14.0
# Books & Magazines                                    8400.0   47.0
# Car electronics                                        39.0    2.0
# Children Clothes & Nurturing products                1338.0   19.0
# Children toys                                         562.0    4.0
# Cleaning & Sanitary                                    12.0    NaN
# Collectibles                                           89.0    3.0
# Concept stores & Miscellaneous                       3909.0   60.0
# Cosmetics                                             559.0   21.0
# Costumes & Party supplies                             135.0    2.0
# Dating services                                       512.0   57.0
# Decoration & Art                                      591.0    8.0
# Dietary supplements                                  2737.0   40.0
# Digital services                                      266.0    5.0
# Diversified Health & Beauty products                  700.0   10.0
# Diversified Home & Garden products                    629.0   12.0
# Diversified Jewelry & Accessories                      46.0    NaN
# Diversified children products                        2656.0   35.0
# Diversified electronics                              1586.0   41.0
# Diversified entertainment                           34528.0  253.0
# Diversified erotic material                           538.0   22.0
# Education                                               1.0    NaN
# Electronic equipment & Related accessories            927.0   19.0
# Erotic Clothing & Accessories                          74.0    NaN
# Event tickets                                          11.0    NaN
# Food & Beverage                                       241.0   22.0
# Fragrances                                            286.0    2.0
# Furniture                                             334.0    6.0
# General Shoes & Clothing                             4093.0   69.0
# Hobby articles                                        799.0   18.0
# Household electronics (whitegoods/appliances)          74.0    1.0
# Jewelry & Watches                                     799.0   16.0
# Kitchenware                                            80.0    2.0
# Music & Movies                                        113.0    1.0
# Musical Instruments & Equipment                        60.0    2.0
# Non                                                    63.0    1.0
# Office machines & Related accessories (excl. co...     15.0    NaN
# Personal care & Body improvement                      326.0    5.0
# Pet supplies                                         1160.0   25.0
# Pharmaceutical products                               329.0    5.0
# Plants & Flowers                                       28.0    4.0
# Prescription optics                                   796.0    7.0
# Prints & Photos                                      1468.0   34.0
# Safety products                                        50.0    NaN
# Sex toys                                               32.0    4.0
# Sports gear & Outdoor                                3296.0   60.0
# Tobacco                                                50.0    8.0
# Tools & Home improvement                              404.0    5.0
# Travel services                                       162.0    3.0
# Underwear                                              73.0    2.0
# Video Games & Related accessories                     573.0   25.0
# Wheels & Tires                                         93.0    6.0
# Wine, Beer & Liquor                                     9.0    NaN
# Youthful Shoes & Clothing                           10261.0  263.0

# %%
default_per_permerchant_category
# Out:
# default                                                  0.0       1.0
# merchant_category
# Adult Shoes & Clothing                              0.974265  0.025735
# Automotive Parts & Accessories                      0.985314  0.014686
# Bags & Wallets                                      1.000000       NaN
# Body & Hair Care                                    0.981723  0.018277
# Books & Magazines                                   0.994436  0.005564
# Car electronics                                     0.951220  0.048780
# Children Clothes & Nurturing products               0.985999  0.014001
# Children toys                                       0.992933  0.007067
# Cleaning & Sanitary                                 1.000000       NaN
# Collectibles                                        0.967391  0.032609
# Concept stores & Miscellaneous                      0.984883  0.015117
# Cosmetics                                           0.963793  0.036207
# Costumes & Party supplies                           0.985401  0.014599
# Dating services                                     0.899824  0.100176
# Decoration & Art                                    0.986644  0.013356
# Dietary supplements                                 0.985596  0.014404
# Digital services                                    0.981550  0.018450
# Diversified Health & Beauty products                0.985915  0.014085
# Diversified Home & Garden products                  0.981279  0.018721
# Diversified Jewelry & Accessories                   1.000000       NaN
# Diversified children products                       0.986994  0.013006
# Diversified electronics                             0.974800  0.025200
# Diversified entertainment                           0.992726  0.007274
# Diversified erotic material                         0.960714  0.039286
# Education                                           1.000000       NaN
# Electronic equipment & Related accessories          0.979915  0.020085
# Erotic Clothing & Accessories                       1.000000       NaN
# Event tickets                                       1.000000       NaN
# Food & Beverage                                     0.916350  0.083650
# Fragrances                                          0.993056  0.006944
# Furniture                                           0.982353  0.017647
# General Shoes & Clothing                            0.983421  0.016579
# Hobby articles                                      0.977968  0.022032
# Household electronics (whitegoods/appliances)       0.986667  0.013333
# Jewelry & Watches                                   0.980368  0.019632
# Kitchenware                                         0.975610  0.024390
# Music & Movies                                      0.991228  0.008772
# Musical Instruments & Equipment                     0.967742  0.032258
# Non                                                 0.984375  0.015625
# Office machines & Related accessories (excl. co...  1.000000       NaN
# Personal care & Body improvement                    0.984894  0.015106
# Pet supplies                                        0.978903  0.021097
# Pharmaceutical products                             0.985030  0.014970
# Plants & Flowers                                    0.875000  0.125000
# Prescription optics                                 0.991283  0.008717
# Prints & Photos                                     0.977364  0.022636
# Safety products                                     1.000000       NaN
# Sex toys                                            0.888889  0.111111
# Sports gear & Outdoor                               0.982122  0.017878
# Tobacco                                             0.862069  0.137931
# Tools & Home improvement                            0.987775  0.012225
# Travel services                                     0.981818  0.018182
# Underwear                                           0.973333  0.026667
# Video Games & Related accessories                   0.958194  0.041806
# Wheels & Tires                                      0.939394  0.060606
# Wine, Beer & Liquor                                 1.000000       NaN
# Youthful Shoes & Clothing                           0.975010  0.024990

# %% [markdown]
# ### Conclusion
# - For age:
#     - The data was splitted based on generations (Generation Z, Millennials, Generation X, and older generations)
#     - As expected millennials are more likely to be using the service
#     - After visualizing the data, the hypothesis that younger generation will high tendency for defaulting than older generation is rejected
# - For name_in_email:
#      - No correlation between the name_in_email and defaulting were detected
# - For merchant_group:
#      - Each group have defaulting probability close to the general defaulting distribution
# - For merchant_category:
#      - Some categories have very high probability of defaulting ( compared to the general defaulting distribution)(e.g. Plants & Flowers, Sex toys, Tobacco)
#      - Other categories like Bags & Wallets, Cleaning & Sanitary, and Safety products have norecords of defaulting

# %% [markdown]
# ## 3. Understand attributes describing loan status
# -  remittance (account_days_in_rem_12_24m, num_arch_rem_0_12m)
# -  direct credit (account_days_in_dc_12_24m, num_arch_dc_0_12m, num_arch_dc_12_24m)
# -  term loan (account_days_in_term_12_24m)
# -  ok transactions ( num_arch_ok_0_12m, num_arch_ok_12_24m)

# %%
days_colms = ['account_days_in_dc_12_24m', 'account_days_in_rem_12_24m', 'account_days_in_term_12_24m', 'num_arch_dc_0_12m', 'num_arch_dc_12_24m', 'num_arch_ok_0_12m', 'num_arch_ok_12_24m', 'num_arch_rem_0_12m']
train_data.boxplot(column=days_colms, figsize=(20, 5))
# Out:
# <AxesSubplot:>

# %%
train_data_days = train_data[['default'] + days_colms].copy()

# %%
for colmn in days_colms:
    train_data_days[colmn] = train_data_days[colmn].apply(lambda x: 0 if x==0  else(1 if x > 0 else "unavailable"))
    plot_default_per_colm_value(train_data_days, colmn)
# Out:
# default                      0.0   1.0
# account_days_in_dc_12_24m
# 0                          77909  1152
# 1                            187    45
# unavailable                10592    91
# default                       0.0  1.0
# account_days_in_rem_12_24m
# 0                           69751  824
# 1                            8345  373
# unavailable                 10592   91
# default                        0.0   1.0
# account_days_in_term_12_24m
# 0                            77120  1077
# 1                              976   120
# unavailable                  10592    91
# default              0.0   1.0
# num_arch_dc_0_12m
# 0                  85135  1019
# 1                   3553   269
# default               0.0   1.0
# num_arch_dc_12_24m
# 0                   85326  1043
# 1                    3362   245
# default              0.0  1.0
# num_arch_ok_0_12m
# 0                  23881  821
# 1                  64807  467
# default               0.0  1.0
# num_arch_ok_12_24m
# 0                   33153  939
# 1                   55535  349
# default               0.0   1.0
# num_arch_rem_0_12m
# 0                   68069  1020
# 1                   20619   268

# %% [markdown]
# ### Conclusion
# - All eight attributes are mostly always Zero
# - Regardless of the value assigned to any of the attributes the defaulting probability almost the same
# - In data engineering phase, all null values will be replaced by Zero

# %% [markdown]
# ## 4. Do in depth analysis of the account's statues, attributes of interest are
#  - account_status
#  - account_worst_status_0_3m
#  - account_worst_status_12_24m
#  - account_worst_status_3_6m
#  - account_worst_status_6_12m
#  - worst_status_active_inv
#  - status_last_archived_0_24m
#  - status_2nd_last_archived_0_24m
#  - status_3rd_last_archived_0_24m
#  - status_max_archived_0_6_months
#  - status_max_archived_0_12_months
#  - status_max_archived_0_24_months

# %%
status_colms = ['account_status', 'account_worst_status_0_3m', 'account_worst_status_12_24m', 'account_worst_status_3_6m', 'account_worst_status_6_12m', 'worst_status_active_inv', 'status_last_archived_0_24m', 'status_2nd_last_archived_0_24m', 'status_3rd_last_archived_0_24m', 'status_max_archived_0_6_months', 'status_max_archived_0_12_months', 'status_max_archived_0_24_months']
train_data.boxplot(column=status_colms, figsize=(15, 5),rot=90)
# Out:
# <AxesSubplot:>

# %%
train_data_status = train_data[['default'] + status_colms].copy()
vc_nulls = train_data[status_colms].apply(lambda x: x.isnull().value_counts()).T[True]
vc_nulls
# Out:
# account_status                     48934.0
# account_worst_status_0_3m          48934.0
# account_worst_status_12_24m        60055.0
# account_worst_status_3_6m          51938.0
# account_worst_status_6_12m         54313.0
# worst_status_active_inv            62540.0
# status_last_archived_0_24m             NaN
# status_2nd_last_archived_0_24m         NaN
# status_3rd_last_archived_0_24m         NaN
# status_max_archived_0_6_months         NaN
# status_max_archived_0_12_months        NaN
# status_max_archived_0_24_months        NaN
# Name: True, dtype: float64

# %%
train_data_status = train_data[['default'] + status_colms].copy()
train_data_status['max'] = train_data_status[status_colms].max(axis=1)
for colmn in (status_colms + ['max']):
    train_data_status[colmn] = train_data_status[colmn].apply(lambda x: x if x >= 0  else "unavailable")
    default_per_colname = plot_default_per_colm_value(train_data_status, colmn)
    print(default_per_colname)
# Out:
# default             0.0    1.0
# account_status
# 1.0             38677.0  668.0
# 2.0              1524.0  163.0
# 3.0                 5.0    2.0
# 4.0                 NaN    3.0
# unavailable     48482.0  452.0
# default              0.0       1.0
# account_status
# 1.0             0.983022  0.016978
# 2.0             0.903379  0.096621
# 3.0             0.714286  0.285714
# 4.0                  NaN  1.000000
# unavailable     0.990763  0.009237
# default                      0.0  1.0
# account_worst_status_0_3m
# 1.0                        34118  406
# 2.0                         5672  350
# 3.0                          341   57
# 4.0                           75   23
# unavailable                48482  452
# default                         0.0       1.0
# account_worst_status_0_3m
# 1.0                        0.988240  0.011760
# 2.0                        0.941880  0.058120
# 3.0                        0.856784  0.143216
# 4.0                        0.765306  0.234694
# unavailable                0.990763  0.009237
# default                        0.0  1.0
# account_worst_status_12_24m
# 1.0                          20978  164
# 2.0                           7390  251
# 3.0                            825   80
# 4.0                            188   45
# unavailable                  59307  748
# default                           0.0       1.0
# account_worst_status_12_24m
# 1.0                          0.992243  0.007757
# 2.0                          0.967151  0.032849
# 3.0                          0.911602  0.088398
# 4.0                          0.806867  0.193133
# unavailable                  0.987545  0.012455
# default                      0.0  1.0
# account_worst_status_3_6m
# 1.0                        31353  355
# 2.0                         5463  276
# 3.0                          413   45
# 4.0                           91   42
# unavailable                51368  570
# default                         0.0       1.0
# account_worst_status_3_6m
# 1.0                        0.988804  0.011196
# 2.0                        0.951908  0.048092
# 3.0                        0.901747  0.098253
# 4.0                        0.684211  0.315789
# unavailable                0.989025  0.010975
# default                       0.0  1.0
# account_worst_status_6_12m
# 1.0                         27345  265
# 2.0                          6980  259
# 3.0                           543   78
# 4.0                           139   54
# unavailable                 53681  632
# default                          0.0       1.0
# account_worst_status_6_12m
# 1.0                         0.990402  0.009598
# 2.0                         0.964222  0.035778
# 3.0                         0.874396  0.125604
# 4.0                         0.720207  0.279793
# unavailable                 0.988364  0.011636
# default                    0.0  1.0
# worst_status_active_inv
# 1.0                      23853  377
# 2.0                       2927  124
# 3.0                        139   16
# unavailable              61769  771
# default                       0.0       1.0
# worst_status_active_inv
# 1.0                      0.984441  0.015559
# 2.0                      0.959358  0.040642
# 3.0                      0.896774  0.103226
# unavailable              0.987672  0.012328
# default                       0.0  1.0
# status_last_archived_0_24m
# 0                           16394  493
# 1                           64216  378
# 2                            6853  201
# 3                            1224  215
# 5                               1    1
# default                          0.0       1.0
# status_last_archived_0_24m
# 0                           0.970806  0.029194
# 1                           0.994148  0.005852
# 2                           0.971506  0.028494
# 3                           0.850591  0.149409
# 5                           0.500000  0.500000
# default                             0.0    1.0
# status_2nd_last_archived_0_24m
# 0                               24477.0  688.0
# 1                               56179.0  291.0
# 2                                6857.0  141.0
# 3                                1173.0  168.0
# 5                                   2.0    NaN
# default                              0.0       1.0
# status_2nd_last_archived_0_24m
# 0                               0.972660  0.027340
# 1                               0.994847  0.005153
# 2                               0.979851  0.020149
# 3                               0.874720  0.125280
# 5                               1.000000       NaN
# default                           0.0  1.0
# status_3rd_last_archived_0_24m
# 0                               30552  815
# 1                               51162  219
# 2                                5945  139
# 3                                1027  114
# 5                                   2    1
# default                              0.0       1.0
# status_3rd_last_archived_0_24m
# 0                               0.974017  0.025983
# 1                               0.995738  0.004262
# 2                               0.977153  0.022847
# 3                               0.900088  0.099912
# 5                               0.666667  0.333333
# default                           0.0  1.0
# status_max_archived_0_6_months
# 0                               31648  855
# 1                               44320  193
# 2                               11253  136
# 3                                1467  104
# default                              0.0       1.0
# status_max_archived_0_6_months
# 0                               0.973695  0.026305
# 1                               0.995664  0.004336
# 2                               0.988059  0.011941
# 3                               0.933800  0.066200
# default                            0.0  1.0
# status_max_archived_0_12_months
# 0                                21050  623
# 1                                45641  233
# 2                                18404  159
# 3                                 3587  271
# 5                                    6    2
# default                               0.0       1.0
# status_max_archived_0_12_months
# 0                                0.971255  0.028745
# 1                                0.994921  0.005079
# 2                                0.991435  0.008565
# 3                                0.929756  0.070244
# 5                                0.750000  0.250000
# default                            0.0  1.0
# status_max_archived_0_24_months
# 0                                16394  493
# 1                                42134  216
# 2                                24132  178
# 3                                 6013  399
# 5                                   15    2
# default                               0.0       1.0
# status_max_archived_0_24_months
# 0                                0.970806  0.029194
# 1                                0.994900  0.005100
# 2                                0.992678  0.007322
# 3                                0.937773  0.062227
# 5                                0.882353  0.117647
# default    0.0  1.0
# max
# 0.0      13134  263
# 1.0      40301  232
# 2.0      27974  275
# 3.0       6898  414
# 4.0        366  102
# 5.0         15    2
# default       0.0       1.0
# max
# 0.0      0.980369  0.019631
# 1.0      0.994276  0.005724
# 2.0      0.990265  0.009735
# 3.0      0.943381  0.056619
# 4.0      0.782051  0.217949
# 5.0      0.882353  0.117647

# %% [markdown]
# ### Conclusion
# - All twelve attributes are categorical
# - Archived status:
#     - can take one of the following values {0, 1, 2, 3, 4, 5}; zero means good status and Five means very bad status
#     - Have no null values
# - Active status:
#     - From my understanding, account_status is kind of a weighted average of the prvious account status
#     - can take one of the following values {1, 2, 3, 4}; no Zero  nor Five!
#     - For each status more than 50% of the values are missing
# - Regardless of the value assigned to any of the attributes the defaulting probability almost the same
# - In data engineering phase:
#     - new attribute will be created capturing the maximum statues for active loans.
#     - Test if using only three attributes, namely (account_status, status_max_archived_0_24_months, maximum statues for active loans) will give good results as all other attributes are kind of correlated to those three attributes
#     - Null values will not be filled nor the record eill be deleted, rather I will use algorithms that support missing values

# %% [markdown]
# ## 5. Test how the increase of paid/added amounts might reduce the probability of defaulting
# - account_amount_added_12_24m
# - max_paid_inv_0_12m
# - max_paid_inv_0_24m
# - sum_capital_paid_account_0_12m
# - sum_capital_paid_account_12_24m

# %%
payment_colms = ['account_amount_added_12_24m', 'max_paid_inv_0_12m', 'max_paid_inv_0_24m', 'sum_capital_paid_account_0_12m', 'sum_capital_paid_account_12_24m']
train_data.boxplot(column=payment_colms, figsize=(20, 5))
# Out:
# <AxesSubplot:>

# %%
for colmn in payment_colms:
    train_data.plot.scatter(x='default', y=colmn, c='DarkBlue')

# %%
# calc max_paid_inv_0_24m
temp_df = train_data[['default'] + payment_colms]
temp_df['max_paid_inv_0_24m'] = temp_df['sum_capital_paid_account_0_12m'] + temp_df['sum_capital_paid_account_12_24m']
train_data.plot.scatter(x='default', y='max_paid_inv_0_24m', c='DarkBlue')
# Out:
# C:\Users\Ahmed\AppData\Local\Temp/ipykernel_13276/971972059.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['max_paid_inv_0_24m'] = temp_df['sum_capital_paid_account_0_12m'] + temp_df['sum_capital_paid_account_12_24m']
# <AxesSubplot:xlabel='default', ylabel='max_paid_inv_0_24m'>

# %% [markdown]
# ### Conclusion
# - Increase in ammounts added or paid lower the probability of defaulting
# - In modeling phase, only max_paid_inv_0_24m, account_amount_added_12_24m, and max_paid_inv_0_24m will be used

# %% [markdown]
# ## 6. Tap into who active invoices and dept history might correlate with defaulting
#  - account_incoming_debt_vs_paid_0_24m
#  - num_active_div_by_paid_inv_0_12m
#  - num_active_inv
#  - num_unpaid_bills
#  - recovery_debt

# %%
dept_colms = ['account_incoming_debt_vs_paid_0_24m', 'num_active_div_by_paid_inv_0_12m', 'num_active_inv', 'num_unpaid_bills', 'recovery_debt']

train_data.boxplot(column=dept_colms, figsize=(20, 5))
# Out:
# <AxesSubplot:>

# %%
dept_train_data = train_data[['default'] + dept_colms]
dept_train_data['num_of_paid_inv_0_12m'] = dept_train_data.apply(lambda row: row['num_active_inv'] / row['num_active_div_by_paid_inv_0_12m'], axis=1)
dept_colms += ['num_of_paid_inv_0_12m']
dept_train_data.describe(percentiles=[0.25, .5, .75, .85, .9, .95])
# Out:
# C:\Users\Ahmed\AppData\Local\Temp/ipykernel_13276/3165390890.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   dept_train_data['num_of_paid_inv_0_12m'] = dept_train_data.apply(lambda row: row['num_active_inv'] / row['num_active_div_by_paid_inv_0_12m'], axis=1)
# C:\Users\Ahmed\AppData\Local\Temp/ipykernel_13276/3165390890.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dept_train_data['num_of_paid_inv_0_12m'] = dept_train_data.apply(lambda row: row['num_active_inv'] / row['num_active_div_by_paid_inv_0_12m'], axis=1)
#             default  account_incoming_debt_vs_paid_0_24m  \
# count  89976.000000                         36619.000000
# mean       0.014315                             1.330536
# std        0.118786                            26.924730
# min        0.000000                             0.000000
# 25%        0.000000                             0.000000
# 50%        0.000000                             0.153818
# 75%        0.000000                             0.664694
# 85%        0.000000                             1.042147
# 90%        0.000000                             1.485513
# 95%        0.000000                             2.781210
# max        1.000000                          3914.000000
#
#        num_active_div_by_paid_inv_0_12m  num_active_inv  num_unpaid_bills  \
# count                      69318.000000    89976.000000      89976.000000
# mean                           0.114667        0.598704          2.142249
# std                            0.293679        1.544341          6.296635
# min                            0.000000        0.000000          0.000000
# 25%                            0.000000        0.000000          0.000000
# 50%                            0.000000        0.000000          0.000000
# 75%                            0.100000        1.000000          2.000000
# 85%                            0.214286        1.000000          3.000000
# 90%                            0.333333        2.000000          5.000000
# 95%                            0.500000        3.000000         10.000000
# max                            9.000000       47.000000        182.000000
#
#        recovery_debt  num_of_paid_inv_0_12m
# count   89976.000000           25508.000000
# mean        4.044401              18.457621
# std       167.324157              27.914482
# min         0.000000               1.000000
# 25%         0.000000               4.000000
# 50%         0.000000               9.000000
# 75%         0.000000              20.000000
# 85%         0.000000              33.000000
# 90%         0.000000              45.000000
# 95%         0.000000              70.000000
# max     36479.000000             278.000000

# %%
dept_train_data = dept_train_data.fillna(0)
#dept_train_data['num_of_paid_inv_0_12m'] = dept_train_data['num_of_paid_inv_0_12m'].fillna(0)
for colmn in dept_colms:
    dept_train_data.plot.scatter(x='default', y=colmn, c='DarkBlue')

# %% [markdown]
# ### Conclusion
# - 63% of account_incoming_debt_vs_paid_0_24m are missing so it will be deleted
# - more than 95% of the data in recovery_debt is Zero and all non zero rows, no much information is obtained (will not be used in modelling)
# - Both num_active_inv & num_unpaid_bills kind of having same graph with different scaling. Going forward only num_unpaid_bills will be kept
# - In data engineering phase, the  num_of_paid_inv_0_12m will be calculated
# - In modeling phase, only num_active_div_by_paid_inv_0_12m, num_unpaid_bills, and num_of_paid_inv_0_12m will be used

# %% [markdown]
# ## 7. Analyze the Written Off loans
#  - num_arch_written_off_0_12m
#  - num_arch_written_off_12_24m

# %%
arch_colms = [ 'num_arch_written_off_0_12m', 'num_arch_written_off_12_24m']
train_data.boxplot(column=arch_colms, figsize=(15, 5))
# Out:
# <AxesSubplot:>

# %%
train_data_arch = train_data[['default'] + arch_colms].copy()
vc_nulls = train_data[arch_colms].apply(lambda x: x.isnull().value_counts()).T[True]
vc_nulls
# Out:
# num_arch_written_off_0_12m     16305
# num_arch_written_off_12_24m    16305
# Name: True, dtype: int64

# %%
train_data_arch = train_data[['default'] + arch_colms].copy()
for colmn in arch_colms:
    default_per_colname = plot_default_per_colm_value(train_data_arch, colmn)
    print(default_per_colname)
# Out:
# default                       0.0  1.0
# num_arch_written_off_0_12m
# 0.0                         72837  826
# 1.0                             6    2
# default                          0.0       1.0
# num_arch_written_off_0_12m
# 0.0                         0.988787  0.011213
# 1.0                         0.750000  0.250000
# default                          0.0    1.0
# num_arch_written_off_12_24m
# 0.0                          72834.0  828.0
# 1.0                              8.0    NaN
# 2.0                              1.0    NaN
# default                           0.0       1.0
# num_arch_written_off_12_24m
# 0.0                          0.988759  0.011241
# 1.0                          1.000000       NaN
# 2.0                          1.000000       NaN

# %% [markdown]
# ### Conclusion
# - Both attributes are mostly always Zero
# - Regardless of the value assigned to any of the attributes the defaulting probability almost the same
# - In data engineering phase, both columns will be removed

# %% [markdown]
# ## 8. Determine if other attributes like age is useful for our modeling
# - avg_payment_span_0_12m
# - avg_payment_span_0_3m
# - time_hours

# %%
train_data.boxplot(column=['time_hours','avg_payment_span_0_12m','avg_payment_span_0_3m'], figsize=(20, 5))
# Out:
# <AxesSubplot:>

# %%
train_data[['time_hours','avg_payment_span_0_12m','avg_payment_span_0_3m']].describe(percentiles=[0.25, .5, .75, .85, .9, .95])
# Out:
#          time_hours  avg_payment_span_0_12m  avg_payment_span_0_3m
# count  89976.000000            68508.000000           45594.000000
# mean      15.336351               17.977933              14.960416
# std        5.030674               12.804216              10.259607
# min        0.000278                0.000000               0.000000
# 25%       11.629167               10.800000               8.400000
# 50%       15.800833               14.904762              13.000000
# 75%       19.548056               21.040124              18.222222
# 85%       20.829097               27.000000              23.000000
# 90%       21.501806               32.000000              27.000000
# 95%       22.347014               41.000000              36.000000
# max       23.999722              260.000000              86.000000

# %%
train_data['time_hours'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Conclusion
# - Both avg_payment_span_0_12m & avg_payment_span_0_3m are mostly missing (Will be deleted)
# - Given the short span of time_hours, it is hard to infer what it represents exactly
